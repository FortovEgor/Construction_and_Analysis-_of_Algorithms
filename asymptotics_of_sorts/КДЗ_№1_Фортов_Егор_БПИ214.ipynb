# %% [markdown]
# # 1) АиСД-2, 2023, задание 5
# # 2) Фортов Егор, БПИ214
# # 3) VS Code
# # 4) По максимуму
# # 5) -

# %% [markdown]
# # Таблица №1 (размеры массивов = [50, 300] с шагом в 50)

# %%
import pandas as pd
 
# Читаем данные из .csv файла и сохраняем их в датафрейм
df = pd.read_csv("table_1_new.csv", ";", index_col=False)
 
# df.head()
display(df)
# print(df)
display(dict(df.iloc[0])) # // вывод первой строки датафрейма
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Размер массива                     Тип массива  Выбор (time)  \
# 0               50             случайные числа 0-5          3598
# 1               50          случайные числа 0-4000          6606
# 2               50    почти отсортированный массив          3470
# 3               50  обратно отсортированный массив          3503
# 4              100             случайные числа 0-5         14390
# 5              100          случайные числа 0-4000         25870
# 6              100    почти отсортированный массив         22020
# 7              100  обратно отсортированный массив         22856
# 8              150             случайные числа 0-5         51116
# ...

# %% [markdown]
# ## Оцениваем: время работы в наносекундах (1)

# %% [markdown]
# ### Заполнение массива:
# #### 1.1) Случайные числа из [0; 5]
# #### 1.2) Случайные числа из [0; 4000]
# #### 1.3) "Почти" отсортированный массив
# #### 1.4) Обратно отсортированный массив

# %% [markdown]
# ### Блок №1:
# ####  ось х - размер массива (6 уникальных размеров)
# #### ось y - время сортировки в наносекундах
# #### 13 кривых - для каждого вида сортировки
#
# #### 4 графика - для каждого вида заполнения массива

# %%
# График №1:
# Вид заполнения массива: случайные числа из [0, 5]
# 13 кривых на данном графике
import matplotlib.pyplot as plt 

sort_types = ['Выбор', 'Пузырёк', 'Пузырек Айв1', 'Пузырёк Айв1+2', 'Вставки', 
              'Бин. вставки', 'Подсчет', 'Цифровая', 'Слияние', 'Быстрая',
              'Пирамидальная', 'Шелла-Циура', 'Шелла-Шелла']
sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 
          'tomato', 'orange', 'darkgreen', 'peru', 'pink', 'darkviolet']


x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[0])['Тип массива'], fontweight='bold')
  plt.axis([30, 320, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# На данном графике наглядно видно, что на сверхмалых размерах массивов
# квадратичные сортировки отрабатывают быстрее их более эффективных 
# по асимптотике соседей

# %%
# График №2:
# Вид заполнения массива: случайные числа из [0, 4000]
# 13 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + 1])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[1])['Тип массива'], fontweight='bold')
  plt.axis([30, 320, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# аналогично

# %%
# График №3:
# Вид заполнения массива: "почти" отсортированный массив
# 13 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + 2])[sort_types_columns[j]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[2])['Тип массива'], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# аналогично

# %%
# График №4:
# Вид заполнения массива: массив, отсортированный в обратном порядке
# 13 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + 3])[sort_types_columns[j]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[3])['Тип массива'], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# аналогично

# %% [markdown]
# ### Блок №2:
# #### ось х - размер массива (6 уникальных размеров)
# #### ось y - время сортировки в наносекундах
# #### 4 кривые - для каждого вида массива
#
# #### 13 графиков - для каждого вида сортировки

# %%
# График №5:
# Вид сортировки: Выбор (№1)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[0]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[0], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# На основании данного графика из-за критически малого размера массива довольно 
# трудно сделать вывод о том, на каких данных сортировка выбором работает лучше.

# %%
# График №6:
# Вид сортировки: Пузырёк (№2)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[1]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[1], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 1500000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Заметим, что на данном графике явн наблюдается асимптотическая
# сложность пузырька квадратичная. Также приметим, 
# что на почти отсортированном массиве пузырек ведет себя 
# чуть лучше благодаря тому, что выполняется меньшее число перестановок

# %%
# График №7:
# Вид сортировки: Пузырёк Айв1 (№3)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[2]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[2], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 1500000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Все тот же квадрат, но с небольшой оптимизацией,
# которую даже невозможно заметить на графике ниже

# %%
# График №8:
# Вид сортировки: Пузырёк Айв1+2 (№4)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[3]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[3], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 1400000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Оптимизированный квадрат, различие заметно
# благодаря второму условию Айверсона: из-за того, что
# мы теперь запоминаем, на какой позиции был обмен на предыдущем шаге
# мы уменьшаем число итераций на следующем шаге. Это хорошо
# видно на примере "почти" отсортированного массива,
# так как там редко происхолят обмены "наиболее левых" и "наиболее правых"
# элементов

# %%
# График №9:
# Вид сортировки: Вставки (№5)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[4]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[4], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 500000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Заметим, что сортировка вставками очень быстро сортирует "почти" отсортрованный 
# массив. Это было ожидаемо, так как она имеет линейную сложность 
# в лучшем случае (когда массив отсортирован)

# %%
# График №10:
# Вид сортировки: Бин. вставки (№6)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[5]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[5], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 500000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# В бин. ставках ситуация в целом такая же, как и в обычных вставках (см.выше)
# Единственное различие в том, что все слуяае отрабатываются чуть быстрее благодаря
# тому, что поиск места для вставки элемента занимает O(log N) вместо O(n)

# %%
# График №11:
# Вид сортировки: Сортировка - подсчет (№7)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[6]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[6], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 10000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# График подтверждает линейную слоность сортировки подсчетом

# %%
# График №12:
# Вид сортировки: Цифровая (№8)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[7]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[7], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 4000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Так же линия

# %%
# График №13:
# Вид сортировки: Слияние (№9)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[8]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[8], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 60000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Сортировка слиянием имеет сложность O(N logN), что и видно на данном графике

# %%
# График №14:
# Вид сортировки: Быстрая (№10)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[9]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[9], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 400000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# В лучшем случае быстрая сортировка имеет сложность O(N log N), 
# что приблизительно видно на графике
# в худшем случае быстрая сортировка ведет себя как квадратичная сортировка,
# что и видно на графике в случае обратно осортированного массива
# касаемо почти отсортированного массива - опорный элемент был выбран первый,
# поэтому при делении массива на части "больше опорного" и "меньше опорного",
# что влечет крайне неравномерную распределенность большого массива на два меньших,
# и это, следовательно, вырождается в квадрат.

# %%
# График №15:
# Вид сортировки: Пирамидальная (№11)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[10]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[10], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 120000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# O(N log N)

# %%
# График №16:
# Вид сортировки: Шелла-Циура (№12)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[11]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[11], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 700000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# O(N^2) в общем случае, в лучшем случае линейна (т к ее родитель это вставки),
# что и видно из графика

# %%
# График №17:
# Вид сортировки: Шелла-Шелла (№13)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[12]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[12], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 5000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# благодаря неудачно выбранному расстоянию (послед. Шелла)
# между сравниваемыми и меняемыми элементами
# сортировка работает за квадрат

# %% [markdown]
# ## Оцениваем: время работы в ЭО (элементарных операциях) (2)

# %% [markdown]
# ### Заполнение массива:
# #### 2.1) Случайные числа из [0; 5]
# #### 2.2) Случайные числа из [0; 4000]
# #### 2.3) "Почти" отсортированный массив
# #### 2.4) Обратно отсортированный массив

# %% [markdown]
# ### Блок №1:
# ####  ось х - размер массива (6 уникальных размеров)
# #### ось y - время сортировки в ЭО (элементарных операциях)
# #### 13 кривых - для каждого вида сортировки
#
# #### 4 графика - для каждого вида заполнения массива

# %%
# График №1:
# Вид заполнения массива: случайные числа из [0, 5]
# 13 кривых на данном графике
import matplotlib.pyplot as plt 

sort_types = ['Выбор', 'Пузырёк', 'Пузырек Айв1', 'Пузырёк Айв1+2', 'Вставки', 
              'Бин. вставки', 'Подсчет', 'Цифровая', 'Слияние', 'Быстрая',
              'Пирамидальная', 'Шелла-Циура', 'Шелла-Шелла']
sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 
          'white', 'orange', 'darkgreen', 'peru', 'pink', 'darkviolet']


x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[0])['Тип массива'], fontweight='bold')
  plt.axis([30, 320, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №2:
# Вид заполнения массива: случайные числа из [0, 4000]
# 13 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + 1])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[1])['Тип массива'], fontweight='bold')
  plt.axis([30, 320, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №3:
# Вид заполнения массива: "почти" отсортированный массив
# 13 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + 2])[sort_types_columns[j]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[2])['Тип массива'], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №4:
# Вид заполнения массива: массив, отсортированный в обратном порядке
# 13 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + 3])[sort_types_columns[j]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[3])['Тип массива'], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %% [markdown]
# ### Блок №2:
# #### ось х - размер массива (6 уникальных размеров)
# #### ось y - время сортировки в наносекундах
# #### 4 кривые - для каждого вида массива
#
# #### 13 графиков - для каждого вида сортировки

# %%
# График №5:
# Вид сортировки: Выбор (№1)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[0]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[0], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №6:
# Вид сортировки: Пузырёк (№2)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[1]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[1], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 500000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №7:
# Вид сортировки: Пузырёк Айв1 (№3)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[2]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[2], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 500000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №8:
# Вид сортировки: Пузырёк Айв1+2 (№4)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[3]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[3], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 2000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №9:
# Вид сортировки: Вставки (№5)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[4]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[4], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 800000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №10:
# Вид сортировки: Бин. вставки (№6)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[5]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[5], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 800000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №11:
# Вид сортировки: Сортировка - подсчет (№7)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[6]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[6], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах
# Замечание: в случае массива с элементами [0, 5]
# размер массива для подсчет равен 6
# во всех отсальных случах 4001
# именно поэтому такая разница в ЭО

# %%
# График №12:
# Вид сортировки: Цифровая (№8)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[7]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[7], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 30000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №13:
# Вид сортировки: Слияние (№9)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[8]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[8], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 70000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №14:
# Вид сортировки: Быстрая (№10)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[9]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[9], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 4000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №15:
# Вид сортировки: Пирамидальная (№11)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[10]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[10], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 90000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №16:
# Вид сортировки: Шелла-Циура (№12)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[11]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[11], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №17:
# Вид сортировки: Шелла-Шелла (№13)
# 4 кривых на данном графике

x = [50, 100, 150, 200, 250, 300]  # размеры массивов
for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(6):
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[12]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[12], fontweight='bold')  # Changes!!!
  plt.axis([30, 320, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах
# Замечание: колебания в графике связаны с кешом машины, на которой проводились тесты
# многие значения в одних случаях могли быть запомненны, а некоторые нет

# %% [markdown]
# # ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# # ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# # ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# ################################################################
# # ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# # ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# # Таблица №2 (размеры массивов = [100, 4100] с шагом в 100)

# %%
import pandas as pd
 
# Читаем данные из .csv файла и сохраняем их в датафрейм
df = pd.read_csv("table_2_new.csv", ";", index_col=False)
 
# df.head()
display(df)
# print(df)
display(dict(df.iloc[0])) # // вывод первой строки датафрейма
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      Размер массива                     Тип массива  Выбор (time)  \
# 0               100             случайные числа 0-5          8819
# 1               100          случайные числа 0-4000          8911
# 2               100    почти отсортированный массив          7610
# 3               100  обратно отсортированный массив          7998
# 4               200             случайные числа 0-5         35868
# ..              ...                             ...           ...
# 159            4000  обратно отсортированный массив      14871864
# 160            4100             случайные числа 0-5      15594948
# 161            4100          случайные числа 0-4000      15633714
# ...

# %% [markdown]
# ## Оцениваем: время работы в наносекундах (1)

# %% [markdown]
# ### Заполнение массива:
# #### 1.1) Случайные числа из [0; 5]
# #### 1.2) Случайные числа из [0; 4000]
# #### 1.3) "Почти" отсортированный массив
# #### 1.4) Обратно отсортированный массив

# %% [markdown]
# ### Блок №1:
# #### ось х - размер массива (41 уникальный размер)
# #### ось y - время сортировки в наносекундах
# #### 13 кривых - для каждого вида сортировки
#
# #### 4 графика - для каждого вида заполнения массива

# %%
# График №1:
# Вид заполнения массива: случайные числа из [0, 5]
# 13 кривых на данном графике
import matplotlib.pyplot as plt 

sort_types = ['Выбор', 'Пузырёк', 'Пузырек Айв1', 'Пузырёк Айв1+2', 'Вставки', 
              'Бин. вставки', 'Подсчет', 'Цифровая', 'Слияние', 'Быстрая',
              'Пирамидальная', 'Шелла-Циура', 'Шелла-Шелла']
sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 
          'tomato', 'orange', 'darkgreen', 'peru', 'pink', 'darkviolet']


x = []  # размеры массивов
for i in range(1, 42):
  x.append(100*i)

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[0])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# На этом графике почти каждой сортировке наглядно сооветсвует ее сложность 
# (в лучшем, худшем и среднем случае соответственно)

# %%
# График №2:
# Вид заполнения массива: случайные числа из [0, 4000]
# 13 кривых на данном графике

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4 + 1])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[1])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# аналогично

# %%
# График №3:
# Вид заполнения массива: "почти" отсортированный массив
# 13 кривых на данном графике

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4 + 2])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[2])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# аналогично

# %%
# График №4:
# Вид заполнения массива: "почти" отсортированный массив
# 13 кривых на данном графике

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4 + 3])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[3])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# аналогично

# %% [markdown]
# ### Блок №2:
# #### ось х - размер массива (41 уникальный размер)
# #### ось y - время сортировки в наносекундах
# #### 4 кривые - для каждого вида массива
#
# #### 13 графиков - для каждого вида сортировки

# %%
# График №5:
# Вид сортировки: Выбор (№1)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[0]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[0], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 10000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Квадратичная сортировка во всех случаях, что и подтвеждает график

# %%
# График №6:
# Вид сортировки: Пузырёк (№2)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[1]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[1], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Снова квадрат
# Замечание: обратно отсортированный массив сортируется дольше всех так как
# в этом случае достигается наибольшее число обменов
# почти отсортированный массив сортируется также дольше всех, так как
# при его составлении массив сначала сортировался, а потом менялись местами
# "почти самые левые" элементы с "почти самыми правыми элементами"

# %%
# График №7:
# Вид сортировки: Пузырёк Айв1 (№3)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[2]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[2], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Условие Айверсона №1 ("Если после выполнения внутреннего цикла не произошло ни одного обмена,")
# на тестируемых массивах не выполняется или выполняется слишком малое число раз
# поэтому эта оптимизация незаметна

# %%
# График №8:
# Вид сортировки: Пузырёк Айв1+2 (№4)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[3]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[3], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 10000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Аналогично

# %%
# График №9:
# Вид сортировки: Вставки (№5)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[4]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[4], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()


# КОММЕНТАРИЙ:

# КОММЕНТАРИЙ:
# Заметим, что сортировка вставками очень быстро сортирует "почти" отсортрованный 
# массив. Это было ожидаемо, так как она имеет линейную сложность 
# в лучшем случае (когда массив отсортирован)

# %%
# График №10:
# Вид сортировки: Бин. вставки (№6)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[5]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[5], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 10000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# В бин. ставках ситуация в целом такая же, как и в обычных вставках (см.выше)
# Единственное различие в том, что все слуяае отрабатываются чуть быстрее благодаря
# тому, что поиск места для вставки элемента занимает O(log N) вместо O(n)

# %%
# График №11:
# Вид сортировки: Подсчёт (№7)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[6]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[6], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()


# КОММЕНТАРИЙ:
# График подтверждает линейную слоность сортировки подсчетом

# %%
# График №12:
# Вид сортировки: Цифровая (№8)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[7]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[7], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 150000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ
# Аналогично

# %%
# График №13:
# Вид сортировки: Слияние (№9)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[8]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[8], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Наглядный O(N log N)

# %%
# График №14:
# Вид сортировки: Быстрая (№10)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[9]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[9], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# В лучшем случае быстрая сортировка имеет сложность O(N log N), 
# что приблизительно видно на графике
# в худшем случае быстрая сортировка ведет себя как квадратичная сортировка,
# что и видно на графике в случае обратно осортированного массива
# касаемо почти отсортированного массива - опорный элемент был выбран первый,
# поэтому при делении массива на части "больше опорного" и "меньше опорного",
# что влечет крайне неравномерную распределенность большого массива на два меньших,
# и это, следовательно, вырождается в квадрат.

# %%
# График №15:
# Вид сортировки: Пирамидальная (№11)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[10]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[10], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 700000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# O(N log N)

# %%
# График №16:
# Вид сортировки: Шелла-Циура (№12)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[11]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[11], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 10000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# O(N^2) в общем случае, в лучшем случае линейна (т к ее родитель это вставки),
# что и видно из графика

# %%
# График №17:
# Вид сортировки: Шелла-Шелла (№13)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (time)', 'Пузырёк (time)', 'Пузырек Айв1 (time)',
                      'Пузырёк Айв1+2 (time)', 'Вставки (time)', 
                      'Бин. вставки (time)', 'Подсчет (time)', 'Цифровая (time)',
                      'Слияние (time)', 'Быстрая (time)', 'Пирамидальная (time)',
                      'Шелла-Циура (time)', 'Шелла-Шелла (time)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    new_value = dict(df.iloc[i * 4 + j])[sort_types_columns[12]]  # Changes!!!
    y.append(new_value)  
    # if (new_value >= 300000 and j == 2):
    #   print("|||", new_value, "|||")
    # if (j == 0):
    #   print(new_value, end=' ')
    # if i >= 11 and i <= 15 and j == 2:
    #   print(new_value, i * 4 + j)
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[12], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 800000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# благодаря неудачно выбранному расстоянию (послед. Шелла)
# между сравниваемыми и меняемыми элементами
# сортировка работает за квадрат

# %% [markdown]
# ## Оцениваем: время работы в ЭО (элементарных операциях) (2)

# %% [markdown]
# ### Заполнение массива:
# #### 2.1) Случайные числа из [0; 5]
# #### 2.2) Случайные числа из [0; 4000]
# #### 2.3) "Почти" отсортированный массив
# #### 2.4) Обратно отсортированный массив

# %% [markdown]
# ### Блок №1:
# ####  ось х - размер массива (6 уникальных размеров)
# #### ось y - время сортировки в ЭО (элементарных операциях)
# #### 13 кривых - для каждого вида сортировки
#
# #### 4 графика - для каждого вида заполнения массива

# %%
# График №1:
# Вид заполнения массива: случайные числа из [0, 5]
# 13 кривых на данном графике
import matplotlib.pyplot as plt 

sort_types = ['Выбор', 'Пузырёк', 'Пузырек Айв1', 'Пузырёк Айв1+2', 'Вставки', 
              'Бин. вставки', 'Подсчет', 'Цифровая', 'Слияние', 'Быстрая',
              'Пирамидальная', 'Шелла-Циура', 'Шелла-Шелла']
sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 
          'white', 'orange', 'darkgreen', 'peru', 'pink', 'darkviolet']


x = []  # размеры массивов
for i in range(1, 42):
  x.append(100*i)

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[0])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 40000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №2:
# Вид заполнения массива: случайные числа из [0, 4000]
# 13 кривых на данном графике

sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4 + 1])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[1])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 40000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №3:
# Вид заполнения массива: "почти" отсортированный массив
# 13 кривых на данном графике

sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4 + 2])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[2])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 40000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах
# Замечание: колебания в графике быстрой сортировки обеспечены
# тем, что количество элементарных операций в циклах и условиях 
# довольно большое (то есть выполнение даже пары условий/циклов 
# существенно оказывает влияние на суммарное количество ЭО)

# %%
# График №4:
# Вид заполнения массива: "почти" отсортированный массив
# 13 кривых на данном графике

sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

for j in range(13):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    y.append(dict(df.iloc[i * 4 + 3])[sort_types_columns[j]])

  plt.plot(x, y, color=colors[j], label=sort_types[j]) 
  plt.title('Значения массива - ' + dict(df.iloc[3])['Тип массива'], fontweight='bold')
  plt.axis([0, 4200, 0, 40000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# В целом такая же ситуация, как и с замером времени в наносекундах
# Замечание: Сортировка Шелла отрабатывает здесь очень быстро в связи с тем, что
# Последовательность Шелла здесь оказалась оптимальной для минимизации
# количества элементов

# %% [markdown]
# ### Блок №2:
# #### ось х - размер массива (41 уникальный размер)
# #### ось y - время сортировки в ЭО
# #### 4 кривые - для каждого вида массива
#
# #### 13 графиков - для каждого вида сортировки

# %%
# График №5:
# Вид сортировки: Выбор (№1)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[0]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[0], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 40000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №6:
# Вид сортировки: Пузырёк (№2)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[1]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[1], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 70000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №7:
# Вид сортировки: Пузырёк Айв1 (№3)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

sort_types_columns = ['Выбор (operations)', 'Пузырёк (operations)', 'Пузырек Айв1 (operations)',
                      'Пузырёк Айв1+2 (operations)', 'Вставки (operations)', 
                      'Бин. вставки (operations)', 'Подсчет (operations)', 'Цифровая (operations)',
                      'Слияние (operations)', 'Быстрая (operations)', 'Пирамидальная (operations)',
                      'Шелла-Циура (operations)', 'Шелла-Шелла (operations)']

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    temp_dict = dict(df.iloc[i * 4 + j])
    column_name = sort_types_columns[2]  # Changes!!!
    new_value = temp_dict[column_name]
    y.append(new_value)  
    # if (j == 2):
    #   print(new_value, end=' ')
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[2], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 70000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №8:
# Вид сортировки: Пузырёк Айв1+2 (№4)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[3]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[3], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 100000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №9:
# Вид сортировки: Вставки (№5)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[4]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[4], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 30000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (наносек.)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №10:
# Вид сортировки: Бин. вставки (№6)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[5]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[5], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 30000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №11:
# Вид сортировки: Подсчёт (№7)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[6]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[6], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 100000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах
# Различие в смещении графиков относительно случая элементов из [0, 5]
# Объясняется тем, что в этом случае количество элементов для массива подсчета равно 6
# в остальных 4001

# %%
# График №12:
# Вид сортировки: Цифровая (№8)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[7]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[7], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 300000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №13:
# Вид сортировки: Слияние (№9)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[8]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[8], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 1000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №14:
# Вид сортировки: Быстрая (№10)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[9]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[9], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 50000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №15:
# Вид сортировки: Пирамидальная (№11)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[10]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[10], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 3000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №16:
# Вид сортировки: Шелла-Циура (№12)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[11]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[11], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 60000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах

# %%
# График №17:
# Вид сортировки: Шелла-Шелла (№13)
# 4 кривых на данном графике

array_type = ["Случ. из [0, 5]", "Случ. из [0, 4000]", "'Почти' отсорт.", "Обратно отсорт."]

for j in range(4):
  y = []  # время сортировки в наносекундах
  for i in range(41):
    # CHANGE THIS LINE:
    y.append(dict(df.iloc[i * 4 + j])[sort_types_columns[12]])  # Changes!!!
    
  plt.plot(x, y, color=colors[j], label=array_type[j]) 
  plt.title('Сортировка - ' + sort_types[12], fontweight='bold')  # Changes!!!
  plt.axis([0, 4200, 0, 10000000]) 
  plt.xlabel('Размер массива', fontweight='bold')
  plt.ylabel('Время сортировки (ЭО)', fontweight='bold')
  plt.legend(loc='best', bbox_to_anchor=(1,1))

plt.show()

# КОММЕНТАРИЙ:
# Такая же ситуация, как и с замером времени в наносекундах
